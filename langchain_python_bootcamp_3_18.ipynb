# %% [markdown]
# <a href="https://colab.research.google.com/github/senjoyee/ai-core-samples/blob/main/langchain_python_bootcamp_3_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain

# %%
# !pip install -qU langchain-openai

# %%
import os
from google.colab import userdata
from langchain_openai import ChatOpenAI
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
llm = ChatOpenAI(model="gpt-3.5-turbo-0125")

# %%
from langchain_community.document_loaders import CSVLoader

# %%
csv_loader = CSVLoader("penguins.csv")

# %%
csv_data = csv_loader.load()

# %%
type(csv_data[0])

# %%
print(csv_data[0].page_content)

# %%
print(csv_data[12].metadata)

# %%
# !pip install beautifulsoup4

# %%
from langchain_community.document_loaders import BSHTMLLoader

# %%
html_loader = BSHTMLLoader("some_website.html")

# %%
html_data = html_loader.load()

# %%
html_data[0].page_content

# %%
# !pip install pypdf

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
pdf_loader = PyPDFLoader("SomeReport.pdf")

# %%
pdf_data = pdf_loader.load()

# %%
print(pdf_data[0].page_content)
